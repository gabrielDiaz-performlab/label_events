# %%
from __future__ import division

import pandas as pd
import numpy as np

import bokeh.plotting as bkP
import bokeh.models as bkM
from bokeh.palettes import Spectral6
from bokeh.embed import file_html
from bokeh.resources import CDN

from collections import namedtuple

bkP.output_notebook()
from bokeh.io import push_notebook
# Out:
# /Users/diaz/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d000c882-f628-4922-9b93-2a87959276b9">Loading BokehJS ...</span>
#     </div>

# %%
from os import getcwd

import getpass
from os import getcwd

user = getpass.getuser()

from Tkinter import *
import Tkinter, Tkconstants, tkFileDialog

root = Tk()
root.directory = tkFileDialog.askdirectory(initialdir=getcwd()+'/Data/', title="Select data directory")
gazeFileTime = root.directory.split('/')[-1]
root.destroy()

# %%
pickleName = gazeFileTime + '_' + user + '.pickle'
pickleLoc = 'LabelledGazeEvents/' + gazeFileTime + '/' + pickleName

gazeEventsDF = pd.read_pickle(pickleLoc)
gazeEventsDF.reset_index()
# Out:
#     index  boxID  trialNum  height     width  startTime      y         x  \
# 0       0    1.0       0.0   400.0  1.033353   2.905419  200.0  3.422095
# 1       0    0.0       0.0   400.0  0.369055   1.450910  200.0  1.635437
# 2       0   24.0       1.0   400.0  0.321295   1.806939  200.0  1.967586
# 3       1   39.0       1.0   400.0  0.160647   2.340982  200.0  2.421306
# 4       2   48.0       1.0   400.0  0.156305   2.979230  200.0  3.057383
# 5       3   49.0       1.0   400.0  0.590487   1.194742  200.0  1.489986
# 6       0   27.0       1.0   400.0  0.712058   3.152903  200.0  3.508932
# 7       0   80.0       3.0   400.0  0.872706   0.191782  200.0  0.628135
# 8       0   76.0       3.0   400.0  0.356029   2.128233  200.0  2.306248
# 9       1   77.0       3.0   400.0  0.646931   1.463935  200.0  1.787401
# 10      2   78.0       3.0   400.0  0.173673   1.073171  200.0  1.160008
# 11      3   79.0       3.0   400.0  0.308269   2.501630  200.0  2.655764
# 12      0   11.0       2.0   400.0  0.976909   0.230858  200.0  0.719313
# 13      0    7.0       2.0   400.0  0.156305   2.154284  200.0  2.232437
# 14      1    8.0       2.0   400.0  0.490626   1.212110  200.0  1.457422
# 15      0   10.0       2.0   400.0  1.345964   2.614517  200.0  3.287499
#
#      endTime eventType
# 0   3.938772   pursuit
# 1   1.819964   saccade
# 2   2.128233   saccade
# 3   2.501630   saccade
# 4   3.135535   saccade
# 5   1.785230   saccade
# 6   3.864961  fixation
# 7   1.064488   pursuit
# 8   2.484263   saccade
# 9   2.110866   saccade
# 10  1.246844   saccade
# 11  2.809899   saccade
# 12  1.207768   pursuit
# 13  2.310590   saccade
# 14  1.702735   saccade
# 15  3.960481  fixation
